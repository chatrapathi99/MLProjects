# %% [raw]
# #Machine learning project pipeline
# 1.Define Problem statemenet
# 2.import all the libraries
# 3.Load the data
# 4.Domain analysis
# 5.Basic checkes
# 6.EDA (exploratory data analysis)
#     --univatiate(single column plots)--box plot,pie, hist
#     --bivariate(two column plots)--scatterplot ,barplot,histogram etc
#     --Multivariate(multiple column plots)--heatmap,pair plot
# 7.data preprocessing
#     --find missing/null values and handle them
#     --find outliers and handle them
#     --convert categorical to numerical(encoding)
# 8.feature engineering/selection
#     --transformation(minimizes skewness-normal distribution)
#     --Scaling(only numerical data--adjust the range of your data)
#     --Drop unwanted columns(after checking correlation)
# 9.Model Creation
#     --Define x and y
#     --split the tarin and test data
#     --train the model
# 10.Model evaluation
#     --use evaluation metrics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [raw]
# # domain analysis
# TV: Continuous numerical feature. Represents the amount of money (often in thousands of dollars) spent on television advertising.
#
# Radio: Continuous numerical feature. Represents the amount of money spent on radio advertising.
#
# Newspaper: Continuous numerical feature. Represents the amount of money spent on print/newspaper advertising.
#
# Sales: Continuous numerical target variable. Represents the total number of units sold or overall revenue generated.Unnamed: 0: An artifact of the CSV export process. This is simply an unneeded default row index that gets imported when the file isn't loaded correctly (e.g., using index_col=0 would typically prevent this).

# %%
hm=df.corr()

# %%
sns.heatmap(data=hm,annot=True)
# Out:
# <Axes: >

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
x=df.drop('Sales',axis=1)
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# ...

# %%
y_train
# Out:
# 79     11.0
# 197    12.8
# 38     10.1
# 24      9.7
# 122    11.6
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: Sales, Length: 160, dtype: float64

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(x_test)

# %%
y_pred
# Out:
# array([16.4080242 , 20.88988209, 21.55384318, 10.60850256, 22.11237326,
#        13.10559172, 21.05719192,  7.46101034, 13.60634581, 15.15506967,
#         9.04831992,  6.65328312, 14.34554487,  8.90349333,  9.68959028,
#        12.16494386,  8.73628397, 16.26507258, 10.27759582, 18.83109103,
#        19.56036653, 13.25103464, 12.33620695, 21.30695132,  7.82740305,
#         5.80957448, 20.75753231, 11.98138077,  9.18349576,  8.5066991 ,
#        12.46646769, 10.00337695, 21.3876709 , 12.24966368, 18.26661538,
#        20.13766267, 14.05514005, 20.85411186, 11.0174441 ,  4.56899622])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1.4607567168117606

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 3.174097353976104

# %%
root_mean_squared_error(y_test,y_pred)
# Out:
# 1.7815996615334502

# %%
r2_score(y_test,y_pred)
# Out:
# 0.899438024100912
