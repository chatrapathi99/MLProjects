# %%
import pandas as pd
import numpy as np
import matplotlab.pyplot as plt
from sklearn.leanerr-model import LinearRegression
df=pd.read_csv("homeprices.csv")
# Out:
#   Cell In[2], line 4
#     from sklearn.leanerr-model import LinearRegression
#                         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlab.pyplot as plt
from sklearn.leanerr-model import LinearRegression
df=pd.read_csv("homeprices.csv")
# Out:
#   Cell In[3], line 4
#     from sklearn.leanerr-model import LinearRegression
#                         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlab.pyplot as plt
from sklearn.linear-model import LinearRegression
df=pd.read_csv("homeprices.csv")
# Out:
#   Cell In[8], line 4
#     from sklearn.linear-model import LinearRegression
#                        ^
# SyntaxError: invalid syntax

# %%
pip install scikit-learn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("homeprices.csv")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/bin/python3.14

# %%
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 2.3 MB/s  0:00:04m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 1.8 MB/s  0:00:04 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 1.8 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 1.4 MB/s  0:00:03 eta 0:00:010m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [matplotlib]8 [matplotlib]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("homeprices.csv")
print(df.head())
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 6
#       3 import matplotlib.pyplot as plt
#       4 from sklearn.linear_model import LinearRegression
# ----> 6 df = pd.read_csv("homeprices.csv")
#       7 print(df.head())
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /Users/chatrapathishivaji

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("age_salary.csv")
print(df.head())
# Out:
#    age  salary
# 0   25   30000
# 1   30   35000
# 2   35   40000
# 3   40   45000
# 4   45   50000

# %%
# %matplotlib inline
plt.xlabel('age')
plt.ylabel('salary')
plt.scatter(df.age, df.salary,color='red',marker='+')

# %%
rg=LinearRegression()
rg.fit(df[['age']],df.salary)
# Out:
# LinearRegression()

# %%
rg.predict(pd.DataFrame({'age': [36]}))
# Out:
# array([40730.33262936])

# %%
rg.predict(pd.DataFrame({'age': [32]}))
# Out:
# array([36738.25237592])

# %%
# %matplotlib inline
plt.xlabel('age')
plt.ylabel('salary')
plt.scatter(df.age, df.salary,color='red',marker='+')
plt.plot(
# Out:
#   Cell In[30], line 5
#     plt.plot(
#              ^
# _IncompleteInputError: incomplete input

# %%
# %matplotlib inline
plt.xlabel('age')
plt.ylabel('salary')
plt.scatter(df.age, df.salary,color='red',marker='+')
plt.plot(df['age'], rg.predict(df[['age']]), color='blue')

# %%
git init
# Out:
#   Cell In[36], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
